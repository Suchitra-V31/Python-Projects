# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchitra-V31/Python-Projects/blob/main/Student_Management_Using_OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class students:
    def __init__(self,r_no,name,Class,mark):
        self.r_no=r_no
        self.name=name
        self.Class=Class
        self.mark=mark
    def accept(self,r_no,name,Class,mark):
        obj=students(r_no,name,Class,mark)
        list1.append(obj)
    def display(self,obj):
        print("ROLL NO: ",obj.r_no)
        print("NAME: ",obj.name)
        print("CLASS: ",obj.Class)
        print("MARK: ",obj.mark)
    def _search_(self,rno):
        for i in range(list1.__len__()):
            if list1[i].r_no==rno:
                return i
    def delete(self,rno):
        i=obj._search_(rno)
        del list1[i]
    def update(self,rno,no):
        i=obj._search_(rno)
        roll=no
        list1[i].r_no==roll 
list1=[]
obj=students(0," ",0,0)
print("*****OPERATIONS USED*****")
print("1.ACCEPT THE STUDENTS")
print("2.DISPLAY STUDENT'S LIST")
print("3.SEARCH FOR A STUDENT")
print("4.DELETE A STUDENT")
print("5.UPDATE A STUDENT")
print("6.EXIT")
obj.accept(1,"SUJI",10,99)
obj.accept(2,"RAJ",10,100)
obj.accept(3,"RAM",10,66)
obj.accept(4,"ANU",10,55)
obj.accept(5,"ARUN",10,78)
for i in range(list1.__len__()):
    obj.display(list1[i])
s=obj._search_(2)
obj.display(list1[s])
obj.delete(3)
print(list1.__len__())
print("LIST AFTER DELETION>>>>")
for i in range(list1.__len__()): 
    obj.display(list1[i])
obj.update(4,3)
print(list1.__len__())
print("LIST AFTER UPDATION>>>>>>>")
for i in range(list1.__len__()):
    obj.display(list1[i])
print("YOU CAN EXIT!!!!!!")
# Out:
# *****OPERATIONS USED*****
# 1.ACCEPT THE STUDENTS
# 2.DISPLAY STUDENT'S LIST
# 3.SEARCH FOR A STUDENT
# 4.DELETE A STUDENT
# 5.UPDATE A STUDENT
# 6.EXIT
# ROLL NO:  1
# NAME:  SUJI
# CLASS:  10
# MARK:  99
# ROLL NO:  2
# NAME:  RAJ
# CLASS:  10
# MARK:  100
# ROLL NO:  3
# NAME:  RAM
# CLASS:  10
# MARK:  66
# ROLL NO:  4
# NAME:  ANU
# CLASS:  10
# MARK:  55
# ROLL NO:  5
# NAME:  ARUN
# CLASS:  10
# MARK:  78
# ROLL NO:  2
# NAME:  RAJ
# CLASS:  10
# MARK:  100
# 4
# LIST AFTER DELETION>>>>
# ROLL NO:  1
# NAME:  SUJI
# CLASS:  10
# MARK:  99
# ROLL NO:  2
# NAME:  RAJ
# CLASS:  10
# MARK:  100
# ROLL NO:  4
# NAME:  ANU
# CLASS:  10
# MARK:  55
# ROLL NO:  5
# NAME:  ARUN
# CLASS:  10
# MARK:  78
# 4
# LIST AFTER UPDATION>>>>>>>
# ROLL NO:  1
# NAME:  SUJI
# CLASS:  10
# MARK:  99
# ROLL NO:  2
# NAME:  RAJ
# CLASS:  10
# MARK:  100
# ROLL NO:  4
# NAME:  ANU
# CLASS:  10
# MARK:  55
# ROLL NO:  5
# NAME:  ARUN
# CLASS:  10
# MARK:  78
# YOU CAN EXIT!!!!!!
