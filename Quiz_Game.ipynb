# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchitra-V31/Python-Projects/blob/main/Quiz_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
quiz={1:{"question": "How many days do we have in a week?",
    "Answer": "Seven"},
      2:{"question":" How many days are there in a year?",
         "Answer": 365 },
      3:{"question":"How many colors are there in a rainbow?",
         "Answer":7},
      4:{"question":"Which animal is known as the ‘Ship of the Desert?",
         "Answer":"Camel"},
      5:{"question":"How many letters are there in the English alphabet?",
          "Answer":26 }}
correct=0
wrong=0
print("LET'S START OUR QUIZ!!!!!")
print("Choose the appropriate answers from the option given below: ")
print(quiz[1]["question"])
print("OPTIONS:")
print("a.Ten")
print("b.Seven")
print("c.One")
Answer1=input("Enter the answer(a/b/c): ")
if Answer1== 'b':
    print("You're correct!!!!!")
    correct+=1
else:
    print("You're wrong....The correct answer is option b.")
    wrong+=1
print(quiz[2]["question"])
print("OPTIONS:")
print("a.365")
print("b.344")
print("c.366")
Answer2=input("Enter the answer: ")
if Answer2=='a':
    print("You're correct!!!!!")
    correct+=1
else:
     print("You're wrong....The correct answer is option a.")
     wrong+=1
print(quiz[3]["question"])
print("OPTIONS:")
print("a.4")
print("b.5")
print("c.7")
Answer3=input("Enter the answer: ")
if Answer3=='c':
    print("You're correct!!!!!")
    correct+=1
else:
    print("You're wrong....The correct answer is option c.")
    wrong+=1
print(quiz[4]["question"])
print("OPTIONS:")
print("a.Camel")
print("b.Horse")
print("c.Lion")
Answer4=input("Enter the answer: ")
if Answer4=='a':
    print("You're correct!!!!!")
    correct+=1
else:
     print("You're wrong....The correct answer is option a.")
     wrong+=1
print(quiz[5]["question"])
print("OPTIONS:")
print("a.24")
print("b.25")
print("c.26")
Answer5=input("Enter the answer: ")
if Answer5=='c':
    print("You're correct!!!!!")
    correct+=1
else:
    print("You're wrong....The correct answer is option c.")
    wrong+=1
print("GAME OVER!!!!!")
print("CORRECT ANSWERS: ",correct)
print("WRONG ANSWERS: ",wrong)
# Out:
# LET'S START OUR QUIZ!!!!!
# Choose the appropriate answers from the option given below:
# How many days do we have in a week?
# OPTIONS:
# a.Ten
# b.Seven
# c.One
# Enter the answer(a/b/c): b
# You're correct!!!!!
#  How many days are there in a year?
# OPTIONS:
# a.365
# b.344
# c.366
# Enter the answer: c
# You're wrong....The correct answer is option a.
# How many colors are there in a rainbow?
# OPTIONS:
# a.4
# b.5
# c.7
# Enter the answer: c
# You're correct!!!!!
# Which animal is known as the ‘Ship of the Desert?
# OPTIONS:
# a.Camel
# b.Horse
# c.Lion
# Enter the answer: a
# You're correct!!!!!
# How many letters are there in the English alphabet?
# OPTIONS:
# a.24
# b.25
# c.26
# Enter the answer: c
# You're correct!!!!!
# GAME OVER!!!!!
# CORRECT ANSWERS:  4
# WRONG ANSWERS:  1
